# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivachikkonda02/Deep-Learning-CNN-Project/blob/main/Processing%20image%20data%20for%20Deep%20Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Getting an image using web get
# !wget 'https://3.bp.blogspot.com/-6fVLKnNTLUk/UwoiyZ-9ntI/AAAAAAAABSM/QcDlRFH_TQc/s1600/Dogs+Puppies+Background+wallpaper+%25286%2529.jpg'
# Out:
# --2024-04-17 09:08:14--  https://3.bp.blogspot.com/-6fVLKnNTLUk/UwoiyZ-9ntI/AAAAAAAABSM/QcDlRFH_TQc/s1600/Dogs+Puppies+Background+wallpaper+%25286%2529.jpg
# Resolving 3.bp.blogspot.com (3.bp.blogspot.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to 3.bp.blogspot.com (3.bp.blogspot.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 283085 (276K) [image/jpeg]
# Saving to: ‘Dogs+Puppies+Background+wallpaper+(6).jpg’
#
# Dogs+Puppies+Backgr 100%[===================>] 276.45K  --.-KB/s    in 0.1s
#
# 2024-04-17 09:08:15 (2.62 MB/s) - ‘Dogs+Puppies+Background+wallpaper+(6).jpg’ saved [283085/283085]

# %%
#importing libraries

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# Laoding an image through matplotlib.image module

img=mpimg.imread("/content/dog.jpg")

img
# Out:
# array([[[120, 139, 133],
#         [128, 147, 141],
#         [129, 148, 142],
#         ...,
#         [172, 141,  87],
#         [172, 141,  87],
#         [171, 140,  86]],
#
#        [[110, 129, 123],
#         [113, 132, 126],
#         [112, 131, 125],
#         ...,
#         [172, 141,  87],
#         [172, 141,  87],
#         [171, 140,  86]],
#
#        [[109, 128, 122],
#         [108, 127, 121],
#         [104, 123, 117],
#         ...,
#         [172, 141,  87],
#         [172, 141,  87],
#         [171, 140,  86]],
#
#        ...,
#
#        [[176, 141,  83],
#         [164, 129,  71],
#         [157, 122,  64],
#         ...,
#         [ 43,  54,  46],
#         [ 42,  53,  45],
#         [ 40,  51,  43]],
#
#        [[169, 134,  76],
#         [165, 130,  72],
#         [165, 130,  72],
#         ...,
#         [ 45,  56,  48],
#         [ 43,  54,  46],
#         [ 42,  53,  45]],
#
#        [[162, 127,  69],
#         [163, 128,  70],
#         [170, 135,  77],
#         ...,
#         [ 46,  57,  49],
#         [ 45,  56,  48],
#         [ 43,  54,  46]]], dtype=uint8)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1200, 1600, 3)

# %%
# Display the image from numpy array

img_plot=plt.imshow(img)

plt.show()

# %%
# Resizing image using pillow library

from PIL import Image

# %%
img= Image.open("/content/dog.jpg")

img_resized=img.resize((200,200))

# %%
# saving a file

img_resized.save('dog_image_resized.jpg')

# %%
img_res=mpimg.imread("/content/dog_image_resized.jpg")

img_res_plot=plt.imshow(img_res)

plt.show()

# %%
img_res.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB images to GrayScale Image Using OpenCV**

# %%
import cv2

# %%
img= cv2.imread("/content/dog.jpg")

type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1200, 1600, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1200, 1600)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1600x1200>

# %%
# Saving the grayscale image

cv2.imwrite("dog_grayscale_image.jpg",grayscale_image)
# Out:
# True
